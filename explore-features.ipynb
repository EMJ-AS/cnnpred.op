# %% [markdown]
# # Importing Data from Yahoo Finance with yfinance

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler

from tsfresh import select_features, extract_features
from tsfresh.utilities.dataframe_functions import impute

from tsfresh.feature_selection.relevance import calculate_relevance_table
from tsfresh.feature_extraction import EfficientFCParameters
from tsfresh import extract_features
from tsfresh.utilities.dataframe_functions import roll_time_series

# %% [markdown]
# ## Historical Price & Volume Data for one Stock

# %%
ticker = "NVDA"
NVDA = yf.download(ticker)
NVDA.info()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6288 entries, 1999-01-22 to 2024-01-18
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6288 non-null   float64
#  1   High       6288 non-null   float64
#  2   Low        6288 non-null   float64
#  3   Close      6288 non-null   float64
#  4   Adj Close  6288 non-null   float64
#  5   Volume     6288 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 343.9 KB

# %%
NVDA = yf.download(ticker, start = "2014-01-01", end = "2018-12-31")
print(NVDA.info())
print(NVDA.head())
print(NVDA.tail())

# %% [markdown]
# ### Setting specific Time Periods

# %%
yf.download(ticker, period  = "ytd")

# %%
yf.download(ticker, period  = "1mo")

# %%
df = yf.download(ticker, period  = "5d")

# %% [markdown]
# ## pandas-ta and ts-fresh.
#
# The pandas-ta documentation is [here](https://twopirllc.github.io/pandas-ta/).
#
# The ts-fresh documentation is [here](https://tsfresh.readthedocs.io/en/latest/text/list_of_features.html)

# %%
def ts_fresh_features(data):

    target = (data['Close'].shift() < data['Close']).astype(int)

    # Required for ts_fresh
    data['id'] = range(len(data))
    data['time'] = data.index

    df_rolled = roll_time_series(data, column_id="id", column_sort="time")

    extraction_settings = EfficientFCParameters()
    extracted_features = extract_features(df_rolled, column_id='id', column_sort='time',
                        default_fc_parameters=extraction_settings,
                        impute_function=impute, show_warnings=False)

    extracted_features.set_index(target.index, inplace=True)

    # impute(extracted_features)
    # features_filtered = select_features(extracted_features, target)

    return extracted_features, target

# %%
# Define time series tickers
ticker = ["NVDA"]
index_tickers = ["^DJI", "^GSPC", "^IXIC"]

# %%
pd.set_option('display.max_rows', 100)

data = yf.download(ticker, period  = "10y")

extracted_features, target = ts_fresh_features(data)
ts_fresh_df = extracted_features[['Volume__benford_correlation', \
                                  'Open__benford_correlation', 'High__benford_correlation']]

relevance_table_clf = calculate_relevance_table(extracted_features, target)
relevance_table_clf.sort_values("p_value", inplace=True)
relevance_table_clf

# %%
data.head()

# %%
# Volume weighted average price requires the DataFrame index to be a DatetimeIndex.
# Replace "datetime" with the appropriate column from your DataFrame
# df.set_index(pd.DatetimeIndex(df["Date"]), inplace=True)

data = pd.DataFrame() # Empty DataFrame

 # OR if you have yfinance installed
data = yf.download(ticker, period  = "10y")
indexes = yf.download(index_tickers, period = "10y").Close
data = pd.concat([data, ts_fresh_df], axis=1)
print(data.shape)

# print(data.ta.indicators())

aberration_df = ta.aberration(data['High'], data['Low'], data['Close'], length=5, \
                                   atr_length=14)
data = pd.concat([data, aberration_df], axis=1)

bbands_df = ta.bbands(data['Close'], length=5, std=2, mamode='sma')
data = pd.concat([data, bbands_df], axis=1)

data['AO_5_34'] = ta.ao(data['High'], data['Low'], fast=5, slow=34)
data['BOP'] = ta.bop(data['Open'], data['High'], data['Low'], data['Close'])
data['MOM_2'] = ta.mom(data['Close'], length=2)
data['MOM_4'] = ta.mom(data['Close'], length=4)
data['MOM_6'] = ta.mom(data['Close'], length=6)
data['SMA_30'] = ta.sma(data['Close'], length=30)
data['SMA_60'] = ta.sma(data['Close'],length=60)
data['SMA_90'] = ta.sma(data['Close'],length=90)
data['RSI_14'] = ta.rsi(close=data['Close'], length=14)
# Volume indicators
data['CMF_20'] = ta.cmf(high=data['High'], low=data['Low'], close=data['Close'], \
                        volume=data['Volume'], length=20)
data['AD'] = ta.ad(high=data['High'], low=data['Low'], close=data['Close'], \
                        volume=data['Volume'])

# Calculate the stochastic oscillator
stoch = ta.stoch(high=data['High'], low=data['Low'], close=data['Close'], k=14, d=3, smooth_k=3)
# Add the stochastic oscillator values to the DataFrame
data['%K_14_3_3'] = stoch['STOCHk_14_3_3']
data['%D_14_3_3'] = stoch['STOCHd_14_3_3']

indexes['MOM_2_DJI'] = ta.mom(indexes['^DJI'], length=2)
indexes['MOM_4_DJI'] = ta.mom(indexes['^DJI'], length=4)
indexes['MOM_6_DJI'] = ta.mom(indexes['^DJI'], length=6)
indexes['SMA_30_DJI'] = ta.sma(indexes['^DJI'], length=30)
indexes['SMA_60_DJI'] = ta.sma(indexes['^DJI'],length=60)
indexes['SMA_90_DJI'] = ta.sma(indexes['^DJI'],length=90)
indexes['RSI_14_DJI'] = ta.rsi(close=indexes['^DJI'], length=14)

indexes['MOM_2_GSPC'] = ta.mom(indexes['^GSPC'], length=2)
indexes['MOM_4_GSPC'] = ta.mom(indexes['^GSPC'], length=4)
indexes['MOM_6_GSPC'] = ta.mom(indexes['^GSPC'], length=6)
indexes['SMA_30_GSPC'] = ta.sma(indexes['^GSPC'], length=30)
indexes['SMA_60_GSPC'] = ta.sma(indexes['^GSPC'],length=60)
indexes['SMA_90_GSPC'] = ta.sma(indexes['^GSPC'],length=90)
indexes['RSI_14_GSPC'] = ta.rsi(close=indexes['^GSPC'], length=14)

indexes['MOM_2_IXIC'] = ta.mom(indexes['^IXIC'], length=2)
indexes['MOM_4_IXIC'] = ta.mom(indexes['^IXIC'], length=4)
indexes['MOM_6_IXIC'] = ta.mom(indexes['^IXIC'], length=6)
indexes['SMA_30_IXIC'] = ta.sma(indexes['^IXIC'], length=30)
indexes['SMA_60_IXIC'] = ta.sma(indexes['^IXIC'],length=60)
indexes['SMA_90_IXIC'] = ta.sma(indexes['^IXIC'],length=90)
indexes['RSI_14_IXIC'] = ta.rsi(close=indexes['^IXIC'], length=14)


assert indexes.shape[0] == data.shape[0]
data = pd.concat([data, indexes], axis=1)
data = data.astype('float64')

data_filtered = data.iloc[100:]

# Initialize the StandardScaler
scaler = StandardScaler()

# Normalize all columns in the DataFrame using z-scaling
df_normalized = pd.DataFrame(scaler.fit_transform(data_filtered), columns=data_filtered.columns)


# Set the index of df2 to be the index of df1
df_normalized.set_index(data_filtered.index, inplace=True)

# %%
df_normalized.index

# %%
for i, c in zip(range(len(df_normalized.columns)), df_normalized.columns):
    print(f'{i}: {c}')

# %%
df_normalized.isnull().sum()
df_normalized.count()
df_normalized.info()

# %%
# Write the DataFrame to a CSV file
df_normalized['Name'] = 'NVDA'
df_normalized.to_csv('./data/data-2d/NVDA//NVDA.csv', index=True)

# %% [markdown]
# ## Frequency Settings (Intraday)

# %%
ticker = "GE"
# yf.download(ticker, period  = "1mo", interval = "1h")
# yf.download(ticker, period  = "1mo", interval = "30m")
# yf.download(ticker, period  = "1mo", interval = "5m")
# yf.download(ticker, period  = "1mo", interval = "1m")
# yf.download(ticker, period  = "5d", interval = "1m")

# %%
GE = yf.download(ticker, period  = "5d", interval = "1m")
GE.head(10)

# %%
GE.describe()

# %%
yf.download(ticker, period  = "5d", prepost= True, interval = "30m")

# %% [markdown]
# ## Stock Splits and Dividends

# %%
ticker = "AAPL"
AAPL = yf.download(ticker, period  = "10y", actions = True)
AAPL.head()

# %%
AAPL[AAPL["Dividends"] > 0]

# %%
AAPL.loc["2019-08-05":"2019-08-15"]

# %%
AAPL.loc["2019-08-05":"2019-08-15"].diff()

# %%
AAPL[AAPL["Stock Splits"] > 0]

# %%
AAPL.loc["2014-06-05":"2014-06-15"]

# %% [markdown]
# ## Exporting to CSV/Excel

# %%
ticker = "GE"

# %%
GE = yf.download(ticker, period  = "5y")
GE.head()

# %%
GE.to_csv("GE.csv")
pd.read_csv("GE.csv", parse_dates = ["Date"], index_col = "Date")

# %%
GE.to_excel("GE.xls", engine = "openpyxl") # engine added
pd.read_excel("GE.xls", parse_dates= ["Date"], index_col= "Date")

# %% [markdown]
# ## Importing Data for many Stocks

# %%
import pandas as pd
import yfinance as yf

# %%
ticker = ["GE", "AAPL", "META"] 
yf.download(ticker, period  = "5y")
# yf.download(ticker, period  = "5y" , group_by= "Ticker")

# %%
stocks = yf.download(ticker, period  = "5y").Close
stocks.head()

# %%
stocks.plot()
plt.show()

# %% [markdown]
# ## Importing Financial Indexes

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["^DJI", "^GSPC", "^IXIC"]
indexes = yf.download(ticker, period  = "1y")
indexes.head(10)
# Out:
# [*********************100%%**********************]  3 of 3 completed
#                Adj Close                                    Close  \
#                     ^DJI        ^GSPC         ^IXIC          ^DJI
# Date
# 2023-01-18  33296.960938  3928.860107  10957.009766  33296.960938
# 2023-01-19  33044.558594  3898.850098  10852.269531  33044.558594
# 2023-01-20  33375.488281  3972.610107  11140.429688  33375.488281
# 2023-01-23  33629.558594  4019.810059  11364.410156  33629.558594
# 2023-01-24  33733.960938  4016.949951  11334.269531  33733.960938
# 2023-01-25  33743.839844  4016.219971  11313.360352  33743.839844
# 2023-01-26  33949.410156  4060.429932  11512.410156  33949.410156
# 2023-01-27  33978.078125  4070.560059  11621.709961  33978.078125
# 2023-01-30  33717.089844  4017.770020  11393.809570  33717.089844
# 2023-01-31  34086.039062  4076.600098  11584.549805  34086.039062
#
#                                                High               \
#                   ^GSPC         ^IXIC          ^DJI        ^GSPC
# Date
# 2023-01-18  3928.860107  10957.009766  34016.531250  4014.159912
# 2023-01-19  3898.850098  10852.269531  33227.488281  3922.939941
# 2023-01-20  3972.610107  11140.429688  33381.949219  3972.959961
# 2023-01-23  4019.810059  11364.410156  33782.878906  4039.310059
# 2023-01-24  4016.949951  11334.269531  33782.921875  4023.919922
# 2023-01-25  4016.219971  11313.360352  33773.089844  4019.550049
# 2023-01-26  4060.429932  11512.410156  33953.789062  4061.570068
# 2023-01-27  4070.560059  11621.709961  34164.328125  4094.209961
# 2023-01-30  4017.770020  11393.809570  34055.289062  4063.850098
# 2023-01-31  4076.600098  11584.549805  34095.230469  4077.159912
#
#                                    Low                             \
#                    ^IXIC          ^DJI        ^GSPC         ^IXIC
# Date
# 2023-01-18  11223.410156  33269.898438  3926.590088  10952.049805
# 2023-01-19  10932.519531  32982.050781  3885.540039  10804.570312
# 2023-01-20  11143.169922  32948.929688  3897.860107  10885.650391
# 2023-01-23  11405.500000  33316.250000  3971.639893  11144.030273
# 2023-01-24  11378.150391  33310.558594  3989.790039  11282.650391
# 2023-01-25  11334.219727  33273.210938  3949.060059  11069.179688
# 2023-01-26  11516.049805  33635.601562  4013.290039  11341.190430
# 2023-01-27  11691.889648  33830.851562  4048.699951  11470.269531
# 2023-01-30  11553.309570  33695.179688  4015.550049  11388.540039
# 2023-01-31  11586.009766  33664.910156  4020.439941  11398.370117
#
#                     Open                                Volume              \
#                     ^DJI        ^GSPC         ^IXIC       ^DJI       ^GSPC
# Date
# 2023-01-18  33948.488281  4002.250000  11170.950195  351670000  4298710000
# 2023-01-19  33171.351562  3911.840088  10890.400391  319770000  3991500000
# 2023-01-20  33073.460938  3909.040039  10924.660156  367330000  4013360000
# 2023-01-23  33439.558594  3978.139893  11171.940430  355220000  3945210000
# 2023-01-24  33444.718750  4001.739990  11302.929688  299310000  3320430000
# 2023-01-25  33538.359375  3982.709961  11146.530273  341720000  3724020000
# 2023-01-26  33771.660156  4036.080078  11458.400391  327000000  3809590000
# 2023-01-27  33952.929688  4053.719971  11470.469727  441260000  3907760000
# 2023-01-30  33909.210938  4049.270020  11512.339844  343920000  3802000000
# 2023-01-31  33803.558594  4020.850098  11398.580078  360240000  4679320000
#
#
#                  ^IXIC
# Date
# 2023-01-18  5288630000
# 2023-01-19  4660800000
# 2023-01-20  5980110000
# 2023-01-23  5997810000
# 2023-01-24  5670860000
# 2023-01-25  5485570000
# 2023-01-26  5732890000
# 2023-01-27  6243800000
# 2023-01-30  5122320000
# 2023-01-31  5695150000

# %%
norm = indexes.div(indexes.iloc[0]).mul(100)
norm.head()

# %%
norm.plot()
plt.show()

# %%
ticker = ["^DJITR", "^SP500TR"]
indexes = yf.download(ticker, period  = "5y").Close
indexes

# %% [markdown]
# ## Importing Currencies / FX

# %%
import pandas as pd
import yfinance as yf

# %%
ticker = "EURUSD=X"
ticker2 = "USDEUR=X"
ticker3 = "USDGBP=X"

# %%
df = yf.download(ticker, period  = "5y")
df.head()

# %% [markdown]
# ## Importing Cryptocurrencies

# %%
import yfinance as yf

# Get the tickers for available cryptocurrencies
cryptocurrencies = yf.Tickers

# %%
ticker = ["BTC-EUR", "ETH-USD"]

# %%
crypt = yf.download(ticker, period  = "5y").Close
crypt.head()

# %%
crypt.plot()
plt.show()

# %% [markdown]
# ## Importing Funds & ETFs

# %%
ticker = "TLT" # iShares 20+ Year Treasury Bond ETF
ticker2 = "OMOIX" # Vivaldi Multi-Strategy Fund Class I

# %%
yf.download(ticker, period  = "5y")

# %%
yf.download(ticker2, period  = "5y")

# %% [markdown]
# ## Importing Treasury Yields

# %%
ticker1 = "^TNX" # 10Y Tresury Yield
ticker2 = "^FVX" # 5Y Treasury Yield

# %%
ticker = ["^TNX", "^FVX"]

# %%
yf.download(ticker, period  = "5y")

# %%
yields = yf.download(ticker, period  = "5y").Close

# %%
import matplotlib.pyplot as plt

# %%
yields.plot()
plt.show()

# %%
ticker = "DIS"

# %% [markdown]
# ## Stock Fundamentals, Meta Data and Performance Metrics

# %% [markdown]
# Note: __yfinance is currently unstable/unreliable__ when it comes to downloading fundamental data with the ticker object. In particular, __ticker.info()__ is flawed.

# %% [markdown]
# __Action required__: Check for the __latest yfinance versions__ and update with the following command (Anaconda Prompt / Terminal):

# %% [markdown]
# pip install yfinance --upgrade

# %% [markdown]
# In the following, I have added an __alternative Yahoo Finance API Wrapper__, which is more stable/reliable: __yahooquery__

# %% [markdown]
# __Action required: Please install yahooquery with the following command (Anaconda Prompt / Terminal):__

# %% [markdown]
# pip install yahooquery

# %% [markdown]
# __yfinance__ (currently not working, please check again with latest yfinance version)

# %%
ticker = "DIS"
dis = yf.Ticker(ticker)
dis.history()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-12-20 00:00:00-05:00  93.239998  94.269997  91.250000  91.269997
# 2023-12-21 00:00:00-05:00  91.930000  92.080002  91.059998  92.019997
# 2023-12-22 00:00:00-05:00  91.620003  92.239998  90.750000  91.019997
# 2023-12-26 00:00:00-05:00  90.839996  91.269997  90.599998  90.949997
# 2023-12-27 00:00:00-05:00  90.910004  90.940002  90.040001  90.379997
# 2023-12-28 00:00:00-05:00  90.089996  90.980003  89.970001  90.400002
# 2023-12-29 00:00:00-05:00  90.120003  90.599998  89.860001  90.290001
# 2024-01-02 00:00:00-05:00  90.099998  91.480003  89.730003  90.709999
# 2024-01-03 00:00:00-05:00  90.230003  92.080002  90.000000  91.650002
# 2024-01-04 00:00:00-05:00  91.940002  91.940002  90.000000  90.559998
# 2024-01-05 00:00:00-05:00  90.410004  91.320000  90.360001  90.900002
# 2024-01-08 00:00:00-05:00  91.550003  91.940002  91.000000  91.550003
# 2024-01-09 00:00:00-05:00  91.050003  91.099998  89.599998  89.669998
# 2024-01-10 00:00:00-05:00  89.820000  89.820000  88.879997  89.290001
# 2024-01-11 00:00:00-05:00  89.389999  89.779999  88.690002  89.449997
# 2024-01-12 00:00:00-05:00  89.650002  90.830002  89.650002  90.349998
# 2024-01-16 00:00:00-05:00  90.290001  93.089996  89.459999  93.050003
# 2024-01-17 00:00:00-05:00  92.580002  93.760002  90.099998  90.339996
# 2024-01-18 00:00:00-05:00  90.660004  92.510002  90.410004  92.209999
# 2024-01-19 00:00:00-05:00  92.320000  93.580002  91.629997  93.059998
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-12-20 00:00:00-05:00  13060600        0.0           0.0
# 2023-12-21 00:00:00-05:00  13037200        0.0           0.0
# 2023-12-22 00:00:00-05:00   9411500        0.0           0.0
# 2023-12-26 00:00:00-05:00   8086900        0.0           0.0
# 2023-12-27 00:00:00-05:00  11123500        0.0           0.0
# 2023-12-28 00:00:00-05:00   8479600        0.0           0.0
# 2023-12-29 00:00:00-05:00   9201300        0.0           0.0
# 2024-01-02 00:00:00-05:00  10587600        0.0           0.0
# 2024-01-03 00:00:00-05:00  11929800        0.0           0.0
# 2024-01-04 00:00:00-05:00  12087400        0.0           0.0
# 2024-01-05 00:00:00-05:00   9084400        0.0           0.0
# 2024-01-08 00:00:00-05:00  11103700        0.0           0.0
# 2024-01-09 00:00:00-05:00  11255100        0.0           0.0
# 2024-01-10 00:00:00-05:00  15091600        0.0           0.0
# 2024-01-11 00:00:00-05:00   9642200        0.0           0.0
# 2024-01-12 00:00:00-05:00  11912800        0.0           0.0
# 2024-01-16 00:00:00-05:00  16780900        0.0           0.0
# 2024-01-17 00:00:00-05:00  15735200        0.0           0.0
# 2024-01-18 00:00:00-05:00  12203200        0.0           0.0
# 2024-01-19 00:00:00-05:00  17114028        0.0           0.0

# %%
dis.info # currently not working
# Out:
# {'address1': '500 South Buena Vista Street',
#  'city': 'Burbank',
#  'state': 'CA',
#  'zip': '91521',
#  'country': 'United States',
#  'phone': '818 560 1000',
#  'website': 'https://www.thewaltdisneycompany.com',
#  'industry': 'Entertainment',
#  'industryKey': 'entertainment',
#  'industryDisp': 'Entertainment',
#  'sector': 'Communication Services',
#  'sectorKey': 'communication-services',
#  'sectorDisp': 'Communication Services',
#  'longBusinessSummary': 'The Walt Disney Company operates as an entertainment company worldwide. It operates through three segments: Entertainment, Sports, and Experiences. The company produces and distributes film and television video streaming content under the ABC Television Network, Disney, Freeform, FX, Fox, National Geographic, and Star brand television channels, as well as ABC television stations and A+E television networks; and produces original content under the ABC Signature, Disney Branded Television, FX Productions, Lucasfilm, Marvel, National Geographic Studios, Pixar, Searchlight Pictures, Twentieth Century Studios, 20th Television, and Walt Disney Pictures banners. It also offers direct-to-consumer streaming services through Disney+, Disney+ Hotstar, Hulu, and Star+; sports-related entertainment services through ESPN, ESPN on ABC, ESPN+ DTC, and Star; sale/licensing of film and episodic content to third-party television and VOD services; theatrical, home entertainment, and music distribution services; DVD and Blu-ray discs, electronic home video licenses, and VOD rental services; staging and licensing of live entertainment events; and post-production services. In addition, the company operates theme parks and resorts comprising Walt Disney World Resort, Disneyland Resort, Disneyland Paris, Hong Kong Disneyland Resort, Shanghai Disney Resort, Disney Cruise Line, Disney Vacation Club, National Geographic Expeditions, and Adventures by Disney, as well as Aulani, a Disney resort and spa in Hawaii. It also licenses its intellectual property to a third party for operations of the Tokyo Disney Resort; licenses trade names, characters, visual, literary, and other IP for use on merchandise, published materials, and games; operates a direct-to-home satellite distribution platform; sells branded merchandise through retail, online, and wholesale businesses; and develops and publishes books, comic books, and magazines. The company was founded in 1923 and is based in Burbank, California.',
#  'fullTimeEmployees': 173250,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Robert A. Iger',
#    'age': 72,
#    'title': 'CEO & Director',
#    'yearBorn': 1951,
#    'fiscalYear': 2022,
#    'totalPay': 11268271,
#    'exercisedValue': 34866408,
#    'unexercisedValue': 778341},
#   {'maxAge': 1,
#    'name': 'Mr. Horacio E. Gutierrez',
#    'age': 58,
#    'title': 'Senior EVP, Chief Compliance Officer & General Counsel',
#    'yearBorn': 1965,
#    'fiscalYear': 2022,
#    'totalPay': 6746194,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristina K. Schake',
#    'age': 52,
#    'title': 'Senior EVP & Chief Communications Officer',
#    'yearBorn': 1971,
#    'fiscalYear': 2022,
#    'totalPay': 3186694,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hugh F. Johnston',
#    'age': 61,
#    'title': 'Senior VP & Chief Financial Officer',
#    'yearBorn': 1962,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alexia Skouras Quadrani',
#    'title': 'Executive Vice President of Investor Relations',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Sonia  Coleman',
#    'age': 51,
#    'title': 'Senior EVP & Chief Human Resources Officer',
#    'yearBorn': 1972,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ronald L. Iden',
#    'age': 76,
#    'title': 'Senior VP & Chief Security Officer',
#    'yearBorn': 1947,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brent A. Woodford',
#    'age': 60,
#    'title': 'Executive Vice President of Controllership, Financial Planning & Tax',
#    'yearBorn': 1963,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mahesh  Samat',
#    'title': 'Executive Vice President of Disney Consumer Products Commercialization for the Asia Pacific region',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Rita  Ferro',
#    'title': 'President of Advertising Sales',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 1,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 4,
#  'overallRisk': 1,
#  'governanceEpochDate': 1704067200,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 92.21,
#  'open': 92.32,
#  'dayLow': 91.63,
#  'dayHigh': 93.58,
#  'regularMarketPreviousClose': 92.21,
#  'regularMarketOpen': 92.32,
#  'regularMarketDayLow': 91.63,
#  'regularMarketDayHigh': 93.58,
#  'dividendRate': 0.6,
#  'dividendYield': 0.0064999997,
#  'exDividendDate': 1701993600,
#  'payoutRatio': 0.0,
#  'fiveYearAvgDividendYield': 1.38,
#  'beta': 1.352,
#  'trailingPE': 72.139534,
#  'forwardPE': 17.861803,
#  'volume': 17114028,
#  'regularMarketVolume': 17114028,
#  'averageVolume': 12703895,
#  'averageVolume10days': 12488460,
#  'averageDailyVolume10Day': 12488460,
#  'bid': 92.96,
#  'ask': 92.99,
#  'bidSize': 900,
#  'askSize': 800,
#  'marketCap': 170329571328,
#  'fiftyTwoWeekLow': 78.73,
#  'fiftyTwoWeekHigh': 118.18,
#  'priceToSalesTrailing12Months': 1.9160112,
#  'fiftyDayAverage': 91.5338,
#  'twoHundredDayAverage': 89.48825,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'USD',
#  'enterpriseValue': 218998423552,
#  'profitMargins': 0.02648,
#  'floatShares': 1828833365,
#  'sharesOutstanding': 1830320000,
#  'sharesShort': 26431463,
#  'sharesShortPriorMonth': 23530416,
#  'sharesShortPreviousMonthDate': 1701302400,
#  'dateShortInterest': 1703808000,
#  'sharesPercentSharesOut': 0.014400001,
#  'heldPercentInsiders': 0.00058,
#  'heldPercentInstitutions': 0.65002,
#  'shortRatio': 2.34,
#  'shortPercentOfFloat': 0.014400001,
#  'impliedSharesOutstanding': 1830320000,
#  'bookValue': 54.25,
#  'priceToBook': 1.7153916,
#  'lastFiscalYearEnd': 1696032000,
#  'nextFiscalYearEnd': 1727654400,
#  'mostRecentQuarter': 1696032000,
#  'earningsQuarterlyGrowth': 0.63,
#  'netIncomeToCommon': 2353999872,
#  'trailingEps': 1.29,
#  'forwardEps': 5.21,
#  'pegRatio': 1.26,
#  'lastSplitFactor': '10000:9865',
#  'lastSplitDate': 1181692800,
#  'enterpriseToRevenue': 2.463,
#  'enterpriseToEbitda': 14.897,
#  '52WeekChange': -0.108909905,
#  'SandP52WeekChange': 0.20347583,
#  'lastDividendValue': 0.3,
#  'lastDividendDate': 1701993600,
#  'exchange': 'NYQ',
#  'quoteType': 'EQUITY',
#  'symbol': 'DIS',
#  'underlyingSymbol': 'DIS',
#  'shortName': 'Walt Disney Company (The)',
#  'longName': 'The Walt Disney Company',
#  'firstTradeDateEpochUtc': -252322200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': 'aef70f8f-79be-3478-9d04-39acf5bad0ef',
#  'messageBoardId': 'finmb_191564',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 93.06,
#  'targetHighPrice': 121.0,
#  'targetLowPrice': 63.0,
#  'targetMeanPrice': 104.15,
#  'targetMedianPrice': 108.0,
#  'recommendationMean': 2.1,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 27,
#  'totalCash': 14181999616,
#  'totalCashPerShare': 7.748,
#  'ebitda': 14700999680,
#  'totalDebt': 50672001024,
#  'quickRatio': 0.851,
#  'currentRatio': 1.052,
#  'totalRevenue': 88898002944,
#  'debtToEquity': 44.838,
#  'revenuePerShare': 48.631,
#  'returnOnAssets': 0.02851,
#  'returnOnEquity': 0.030620001,
#  'freeCashflow': 5724375040,
#  'operatingCashflow': 9866000384,
#  'earningsGrowth': 0.623,
#  'revenueGrowth': 0.054,
#  'grossMargins': 0.33405998,
#  'ebitdaMargins': 0.16537,
#  'operatingMargins': 0.101969995,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 0.4559}

# %%
pd.Series(dis.info)
# Out:
# address1             500 South Buena Vista Street
# city                                      Burbank
# state                                          CA
# zip                                         91521
# country                             United States
#                                  ...
# grossMargins                              0.33406
# ebitdaMargins                             0.16537
# operatingMargins                          0.10197
# financialCurrency                             USD
# trailingPegRatio                           0.4559
# Length: 131, dtype: object

# %%
df = pd.Series(dis.info, name = "DIS").to_frame().T
df
# Out:
#                          address1     city state    zip        country  \
# DIS  500 South Buena Vista Street  Burbank    CA  91521  United States
#
#             phone                               website       industry  \
# DIS  818 560 1000  https://www.thewaltdisneycompany.com  Entertainment
#
#        industryKey   industryDisp  ... returnOnEquity freeCashflow  \
# DIS  entertainment  Entertainment  ...        0.03062   5724375040
#
#     operatingCashflow earningsGrowth revenueGrowth grossMargins ebitdaMargins  \
# DIS        9866000384          0.623         0.054      0.33406       0.16537
#
#     operatingMargins financialCurrency trailingPegRatio
# DIS          0.10197               USD           0.4559
#
# [1 rows x 131 columns]

# %%
ticker = ["MSFT", "META"] # FB is now META!

# %%
for i in ticker:
    df.loc["{}".format(i)] = pd.Series(yf.Ticker(i).info)

# %%
df
# Out:
#                           address1        city state         zip  \
# DIS   500 South Buena Vista Street     Burbank    CA       91521
# MSFT             One Microsoft Way     Redmond    WA  98052-6399
# META              1601 Willow Road  Menlo Park    CA       94025
#
#             country         phone                               website  \
# DIS   United States  818 560 1000  https://www.thewaltdisneycompany.com
# MSFT  United States  425 882 8080             https://www.microsoft.com
# META  United States  650 543 4800               https://investor.fb.com
#
#                             industry                   industryKey  \
# DIS                    Entertainment                 entertainment
# MSFT       Software - Infrastructure       software-infrastructure
# META  Internet Content & Information  internet-content-information
#
#                         industryDisp  ... returnOnEquity freeCashflow  \
# DIS                    Entertainment  ...        0.03062   5724375040
# MSFT       Software - Infrastructure  ...        0.39107  51013873664
# META  Internet Content & Information  ...        0.22275  29440124928
#
#      operatingCashflow earningsGrowth revenueGrowth grossMargins  \
# DIS         9866000384          0.623         0.054      0.33406
# MSFT       94966996992          0.272         0.128      0.69511
# META       66219999232          1.679         0.232      0.80115
#
#      ebitdaMargins operatingMargins financialCurrency trailingPegRatio
# DIS        0.16537          0.10197               USD           0.4559
# MSFT        0.5015          0.47587               USD           2.3494
# META       0.42583          0.41375               USD           0.8725
#
# [3 rows x 131 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, DIS to META
# Columns: 131 entries, address1 to trailingPegRatio
# dtypes: object(131)
# memory usage: 3.1+ KB

# %% [markdown]
# __NEW__ (Jan 2023): fast_info | Update: fast_info changed to get_fast_info

# %%
fast_info = dis.get_fast_info # Updated
fast_info()
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']

# %%
for key in fast_info():
    print(f'{key}: {fast_info()[key]}')

# %% [markdown]
# __yahooquery__

# %%
from yahooquery import Ticker

# %%
yq = Ticker(symbols = ticker)  
yq.summary_detail
yq.balance_sheet().shape
# Out:
# (7, 85)

# %%
yq.cash_flow()
# Out:
#          asOfDate periodType currencyCode  AssetImpairmentCharge  \
# symbol
# META   2020-12-31        12M          USD           0.000000e+00
# META   2021-12-31        12M          USD           0.000000e+00
# META   2022-12-31        12M          USD           2.218000e+09
# META   2023-09-30        TTM          USD           3.147000e+09
# MSFT   2020-06-30        12M          USD                    NaN
# MSFT   2021-06-30        12M          USD                    NaN
# MSFT   2022-06-30        12M          USD                    NaN
# MSFT   2023-06-30        12M          USD                    NaN
# MSFT   2023-09-30        TTM          USD                    NaN
#
#         BeginningCashPosition  CapitalExpenditure  CashDividendsPaid  \
# symbol
# META             1.927900e+10       -1.516300e+10                NaN
# META             1.795400e+10       -1.869000e+10                NaN
# META             1.686500e+10       -3.143100e+10                NaN
# META             1.525100e+10       -2.864400e+10                NaN
# MSFT             1.135600e+10       -1.544100e+10      -1.513700e+10
# MSFT             1.357600e+10       -2.062200e+10      -1.652100e+10
# MSFT             1.422400e+10       -2.388600e+10      -1.813500e+10
# MSFT             1.393100e+10       -2.810700e+10      -1.980000e+10
# MSFT             2.288400e+10       -3.174100e+10      -2.023000e+10
#
#         CashFlowFromContinuingFinancingActivities  \
# symbol
# META                                -1.029200e+10
# META                                -5.072800e+10
# META                                -2.213600e+10
# META                                -1.815900e+10
# MSFT                                -4.603100e+10
# MSFT                                -4.848600e+10
# MSFT                                -5.887600e+10
# MSFT                                -4.393500e+10
# MSFT                                -1.829100e+10
#
#         CashFlowFromContinuingInvestingActivities  \
# symbol
# META                                -3.005900e+10
# META                                -7.570000e+09
# META                                -2.897000e+10
# META                                -2.555400e+10
# MSFT                                -1.222300e+10
# MSFT                                -2.757700e+10
# MSFT                                -3.031100e+10
# MSFT                                -2.268000e+10
# MSFT                                -1.904500e+10
#
#         CashFlowFromContinuingOperatingActivities  ...  OtherNonCashItems  \
# symbol                                             ...
# META                                 3.874700e+10  ...       8.500000e+07
# META                                 5.768300e+10  ...       1.050000e+08
# META                                 5.047500e+10  ...       1.519000e+09
# META                                 6.622000e+10  ...       1.726000e+09
# MSFT                                 6.067500e+10  ...                NaN
# MSFT                                 7.674000e+10  ...                NaN
# MSFT                                 8.903500e+10  ...                NaN
# MSFT                                 8.758200e+10  ...                NaN
# MSFT                                 9.496700e+10  ...                NaN
#
#         PurchaseOfBusiness  PurchaseOfInvestment  PurchaseOfPPE  \
# symbol
# META         -3.880000e+08         -4.029100e+10  -1.516300e+10
# META         -8.510000e+08         -3.045400e+10  -1.869000e+10
# META         -1.312000e+09         -9.631000e+09  -3.143100e+10
# META         -6.270000e+08         -2.556000e+09  -2.864400e+10
# MSFT         -2.521000e+09         -7.719000e+10  -1.544100e+10
# MSFT         -8.909000e+09         -6.292400e+10  -2.062200e+10
# MSFT         -2.203800e+10         -2.645600e+10  -2.388600e+10
# MSFT         -1.670000e+09         -3.765100e+10  -2.810700e+10
# MSFT         -2.507000e+09         -4.109800e+10  -3.174100e+10
#
#         RepaymentOfDebt  RepurchaseOfCapitalStock  SaleOfInvestment  \
# symbol
# META      -6.040000e+08             -6.272000e+09      2.577100e+10
# META      -6.770000e+08             -4.453700e+10      4.258600e+10
# META      -8.500000e+08             -2.795600e+10      1.315800e+10
# META      -9.860000e+08             -2.069500e+10      6.088000e+09
# MSFT      -5.518000e+09             -2.296800e+10      8.417000e+10
# MSFT      -3.750000e+09             -2.738500e+10      6.580000e+10
# MSFT      -9.023000e+09             -3.269600e+10      4.489400e+10
# MSFT      -2.750000e+09             -2.224500e+10      4.786400e+10
# MSFT      -3.250000e+09             -2.150300e+10      5.953900e+10
#
#           SaleOfPPE  StockBasedCompensation  \
# symbol
# META     48000000.0            6.536000e+09
# META    123000000.0            9.164000e+09
# META    245000000.0            1.199200e+10
# META    203000000.0            1.361100e+10
# MSFT            NaN            5.289000e+09
# MSFT            NaN            6.118000e+09
# MSFT            NaN            7.502000e+09
# MSFT            NaN            9.611000e+09
# MSFT            NaN            9.926000e+09
#
#         UnrealizedGainLossOnInvestmentSecurities
# symbol
# META                                  33000000.0
# META                                -232000000.0
# META                                 463000000.0
# META                                         NaN
# MSFT                                         NaN
# MSFT                                         NaN
# MSFT                                         NaN
# MSFT                                         NaN
# MSFT                                         NaN
#
# [9 rows x 66 columns]

# %%
yq.earning_history
# Out:
#             maxAge  epsActual  epsEstimate  epsDifference  surprisePercent  \
# symbol row
# MSFT   0         1       2.32         2.29           0.03            0.013
#        1         1       2.45         2.23           0.22            0.099
#        2         1       2.69         2.55           0.14            0.055
#        3         1       2.73         2.42           0.31            0.128
# META   0         1       1.76         2.22          -0.46           -0.207
#        1         1       2.20         2.03           0.17            0.084
#        2         1       2.98         2.91           0.07            0.024
#        3         1       4.00         3.31           0.69            0.208
#
#                quarter period
# symbol row
# MSFT   0    2022-12-31    -4q
#        1    2023-03-31    -3q
#        2    2023-06-30    -2q
#        3    2023-09-30    -1q
# META   0    2022-12-31    -4q
#        1    2023-03-31    -3q
#        2    2023-06-30    -2q
#        3    2023-09-30    -1q

# %%
yq.key_stats['MSFT']
# Out:
# {'maxAge': 1,
#  'priceHint': 2,
#  'enterpriseValue': 2889081159680,
#  'forwardPE': 30.78533,
#  'profitMargins': 0.35314998,
#  'floatShares': 7425796261,
#  'sharesOutstanding': 7432260096,
#  'sharesShort': 51394982,
#  'sharesShortPriorMonth': 49279547,
#  'sharesShortPreviousMonthDate': '2023-11-29 16:00:00',
#  'dateShortInterest': '2023-12-28 16:00:00',
#  'sharesPercentSharesOut': 0.0069,
#  'heldPercentInsiders': 0.00055,
#  'heldPercentInstitutions': 0.73023003,
#  'shortRatio': 1.94,
#  'shortPercentOfFloat': 0.0069,
#  'beta': 0.876,
#  'impliedSharesOutstanding': 7432260096,
#  'category': None,
#  'bookValue': 29.702,
#  'priceToBook': 13.422329,
#  'fundFamily': None,
#  'legalType': None,
#  'lastFiscalYearEnd': '2023-06-29 17:00:00',
#  'nextFiscalYearEnd': '2024-06-29 17:00:00',
#  'mostRecentQuarter': '2023-09-29 17:00:00',
#  'earningsQuarterlyGrowth': 0.27,
#  'netIncomeToCommon': 77096001536,
#  'trailingEps': 10.32,
#  'forwardEps': 12.95,
#  'pegRatio': 2.27,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': '2003-02-17 16:00:00',
#  'enterpriseToRevenue': 13.234,
#  'enterpriseToEbitda': 26.388,
#  '52WeekChange': 0.639622,
#  'SandP52WeekChange': 0.20347583,
#  'lastDividendValue': 0.75,
#  'lastDividendDate': 1700006400}

# %%
yq.financial_data['MSFT'] # financial data
# Out:
# {'maxAge': 86400,
#  'currentPrice': 398.67,
#  'targetHighPrice': 480.0,
#  'targetLowPrice': 298.1,
#  'targetMeanPrice': 419.73,
#  'targetMedianPrice': 420.5,
#  'recommendationMean': 1.7,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 44,
#  'totalCash': 143945007104,
#  'totalCashPerShare': 19.368,
#  'ebitda': 109482999808,
#  'totalDebt': 105681002496,
#  'quickRatio': 1.531,
#  'currentRatio': 1.663,
#  'totalRevenue': 218310000640,
#  'debtToEquity': 47.881,
#  'revenuePerShare': 29.347,
#  'returnOnAssets': 0.14718,
#  'returnOnEquity': 0.39106998,
#  'freeCashflow': 51013873664,
#  'operatingCashflow': 94966996992,
#  'earningsGrowth': 0.272,
#  'revenueGrowth': 0.128,
#  'grossMargins': 0.69511,
#  'ebitdaMargins': 0.5015,
#  'operatingMargins': 0.47587,
#  'profitMargins': 0.35314998,
#  'financialCurrency': 'USD'}

# %%
yq.summary_detail['MSFT'] # summary statistics

# %%
df = pd.Series(yq.key_stats['MSFT']).to_frame().T
df

# %%
df.index = ['MSFT']
df

# %%
ticker = ["MSFT", "META"] # FB is now META!

# %%
for i in ticker:
    df.loc["{}".format(i)] = pd.Series(Ticker(symbols = i).key_stats[i])

# %%
df

# %% [markdown]
# ## Importing Financials (Balance Sheet, P&L, Cashflows)

# %% [markdown]
# __yfinance__ (currently not working, please check again with latest yfinance version)

# %%
dis
type(dis)
# Out:
# yfinance.ticker.Ticker

# %%
dis.balance_sheet
# Out:
#                                                      2023-09-30  \
# Treasury Shares Number                               19000000.0
# Ordinary Shares Number                             1830000000.0
# Share Issued                                       1849000000.0
# Net Debt                                          32249000000.0
# Total Debt                                        49895000000.0
# ...                                                         ...
# Receivables Adjustments Allowances                 -115000000.0
# Other Receivables                                  2266000000.0
# Accounts Receivable                               10179000000.0
# Cash Cash Equivalents And Short Term Investments  14182000000.0
# Cash And Cash Equivalents                         14182000000.0
#
#                                                      2022-09-30  \
# Treasury Shares Number                               19000000.0
# Ordinary Shares Number                             1781000000.0
# Share Issued                                       1800000000.0
# Net Debt                                          36754000000.0
# Total Debt                                        51608000000.0
# ...                                                         ...
# Receivables Adjustments Allowances                 -158000000.0
# Other Receivables                                  1999000000.0
# Accounts Receivable                               10811000000.0
# Cash Cash Equivalents And Short Term Investments  11615000000.0
# Cash And Cash Equivalents                         11615000000.0
#
#                                                      2021-09-30     2020-09-30
# Treasury Shares Number                               19000000.0     19000000.0
# Ordinary Shares Number                             1818000000.0   1807063365.0
# Share Issued                                       1837000000.0   1826063365.0
# Net Debt                                          38447000000.0  40714000000.0
# Total Debt                                        57635000000.0  61539000000.0
# ...                                                         ...            ...
# Receivables Adjustments Allowances                 -170000000.0   -426000000.0
# Other Receivables                                  2360000000.0   1835000000.0
# Accounts Receivable                               11177000000.0  11299000000.0
# Cash Cash Equivalents And Short Term Investments  15959000000.0  17914000000.0
# Cash And Cash Equivalents                         15959000000.0  17914000000.0
#
# [73 rows x 4 columns]

# %%
dis.income_stmt # income_stmt instead of financials!
# Out:
#                                                        2023-09-30  \
# Tax Effect Of Unusual Items                         -1075947000.0
# Tax Rate For Calcs                                          0.289
# Normalized EBITDA                                   15834000000.0
# Total Unusual Items                                 -3723000000.0
# Total Unusual Items Excluding Goodwill              -3723000000.0
# Net Income From Continuing Operation Net Minori...   2354000000.0
# Reconciled Depreciation                              5369000000.0
# Reconciled Cost Of Revenue                          59201000000.0
# EBITDA                                              12111000000.0
# EBIT                                                 6742000000.0
# Net Interest Income                                 -1209000000.0
# Interest Expense                                     1973000000.0
# Interest Income                                       764000000.0
# Normalized Income                                    5001053000.0
# Net Income From Continuing And Discontinued Ope...   2354000000.0
# Total Expenses                                      79906000000.0
# Diluted Average Shares                               1830000000.0
# Basic Average Shares                                 1828000000.0
# Diluted EPS                                                  1.29
# Basic EPS                                                    1.29
# Diluted NI Availto Com Stockholders                  2354000000.0
# Net Income Common Stockholders                       2354000000.0
# Net Income                                           2354000000.0
# Minority Interests                                  -1036000000.0
# Net Income Including Noncontrolling Interests        3390000000.0
# Net Income Discontinuous Operations                           0.0
# Net Income Continuous Operations                     3390000000.0
# Tax Provision                                        1379000000.0
# Pretax Income                                        4769000000.0
# Other Income Expense                                -3014000000.0
# Other Non Operating Income Expenses                   -73000000.0
# Special Income Charges                              -3892000000.0
# Gain On Sale Of Business                                      NaN
# Other Special Charges                                         NaN
# Restructuring And Mergern Acquisition                3892000000.0
# Earnings From Equity Interest                         782000000.0
# Gain On Sale Of Security                              169000000.0
# Net Non Operating Interest Income Expense           -1209000000.0
# Interest Expense Non Operating                       1973000000.0
# Interest Income Non Operating                         764000000.0
# Operating Income                                     8992000000.0
# Operating Expense                                   20705000000.0
# Depreciation Amortization Depletion Income Stat...   5369000000.0
# Depreciation And Amortization In Income Statement    5369000000.0
# Selling General And Administration                  15336000000.0
# Gross Profit                                        29697000000.0
# Cost Of Revenue                                     59201000000.0
# Total Revenue                                       88898000000.0
# Operating Revenue                                   88898000000.0
#
#                                                        2022-09-30  \
# Tax Effect Of Unusual Items                          -295200000.0
# Tax Rate For Calcs                                          0.328
# Normalized EBITDA                                   12897000000.0
# Total Unusual Items                                  -900000000.0
# Total Unusual Items Excluding Goodwill               -900000000.0
# Net Income From Continuing Operation Net Minori...   3193000000.0
# Reconciled Depreciation                              5163000000.0
# Reconciled Cost Of Revenue                          54401000000.0
# EBITDA                                              11997000000.0
# EBIT                                                 6834000000.0
# Net Interest Income                                 -1397000000.0
# Interest Expense                                     1549000000.0
# Interest Income                                       152000000.0
# Normalized Income                                    3797800000.0
# Net Income From Continuing And Discontinued Ope...   3145000000.0
# Total Expenses                                      75952000000.0
# Diluted Average Shares                               1827000000.0
# Basic Average Shares                                 1822000000.0
# Diluted EPS                                                  1.72
# Basic EPS                                                    1.73
# Diluted NI Availto Com Stockholders                  3145000000.0
# Net Income Common Stockholders                       3145000000.0
# Net Income                                           3145000000.0
# Minority Interests                                   -360000000.0
# Net Income Including Noncontrolling Interests        3505000000.0
# Net Income Discontinuous Operations                   -48000000.0
# Net Income Continuous Operations                     3553000000.0
# Tax Provision                                        1732000000.0
# Pretax Income                                        5285000000.0
# Other Income Expense                                  -88000000.0
# Other Non Operating Income Expenses                    -4000000.0
# Special Income Charges                               -237000000.0
# Gain On Sale Of Business                                      0.0
# Other Special Charges                                         NaN
# Restructuring And Mergern Acquisition                 237000000.0
# Earnings From Equity Interest                         816000000.0
# Gain On Sale Of Security                             -663000000.0
# Net Non Operating Interest Income Expense           -1397000000.0
# Interest Expense Non Operating                       1549000000.0
# Interest Income Non Operating                         152000000.0
# Operating Income                                     6770000000.0
# Operating Expense                                   21551000000.0
# Depreciation Amortization Depletion Income Stat...   5163000000.0
# Depreciation And Amortization In Income Statement    5163000000.0
# Selling General And Administration                  16388000000.0
# Gross Profit                                        28321000000.0
# Cost Of Revenue                                     54401000000.0
# Total Revenue                                       82722000000.0
# Operating Revenue                                   82722000000.0
#
#                                                        2021-09-30  \
# Tax Effect Of Unusual Items                            -6540000.0
# Tax Rate For Calcs                                           0.01
# Normalized EBITDA                                    9732000000.0
# Total Unusual Items                                  -654000000.0
# Total Unusual Items Excluding Goodwill               -654000000.0
# Net Income From Continuing Operation Net Minori...   2024000000.0
# Reconciled Depreciation                              5111000000.0
# Reconciled Cost Of Revenue                          45131000000.0
# EBITDA                                               9078000000.0
# EBIT                                                 3967000000.0
# Net Interest Income                                 -1406000000.0
# Interest Expense                                     1406000000.0
# Interest Income                                       140000000.0
# Normalized Income                                    2671460000.0
# Net Income From Continuing And Discontinued Ope...   1995000000.0
# Total Expenses                                      63759000000.0
# Diluted Average Shares                               1828000000.0
# Basic Average Shares                                 1816000000.0
# Diluted EPS                                                  1.09
# Basic EPS                                                     1.1
# Diluted NI Availto Com Stockholders                  1995000000.0
# Net Income Common Stockholders                       1995000000.0
# Net Income                                           1995000000.0
# Minority Interests                                   -512000000.0
# Net Income Including Noncontrolling Interests        2507000000.0
# Net Income Discontinuous Operations                   -29000000.0
# Net Income Continuous Operations                     2536000000.0
# Tax Provision                                          25000000.0
# Pretax Income                                        2561000000.0
# Other Income Expense                                  308000000.0
# Other Non Operating Income Expenses                   201000000.0
# Special Income Charges                               -654000000.0
# Gain On Sale Of Business                              312000000.0
# Other Special Charges                                         NaN
# Restructuring And Mergern Acquisition                 654000000.0
# Earnings From Equity Interest                         761000000.0
# Gain On Sale Of Security                             -111000000.0
# Net Non Operating Interest Income Expense           -1406000000.0
# Interest Expense Non Operating                       1406000000.0
# Interest Income Non Operating                         140000000.0
# Operating Income                                     3659000000.0
# Operating Expense                                   18628000000.0
# Depreciation Amortization Depletion Income Stat...   5111000000.0
# Depreciation And Amortization In Income Statement    5111000000.0
# Selling General And Administration                  13517000000.0
# Gross Profit                                        22287000000.0
# Cost Of Revenue                                     45131000000.0
# Total Revenue                                       67418000000.0
# Operating Revenue                                   67418000000.0
#
#                                                        2020-09-30
# Tax Effect Of Unusual Items                         -1548450000.0
# Tax Rate For Calcs                                           0.27
# Normalized EBITDA                                   10828000000.0
# Total Unusual Items                                 -5735000000.0
# Total Unusual Items Excluding Goodwill              -5735000000.0
# Net Income From Continuing Operation Net Minori...  -2832000000.0
# Reconciled Depreciation                              5345000000.0
# Reconciled Cost Of Revenue                          43880000000.0
# EBITDA                                               5093000000.0
# EBIT                                                 -252000000.0
# Net Interest Income                                 -1491000000.0
# Interest Expense                                     1491000000.0
# Interest Income                                       156000000.0
# Normalized Income                                    1354550000.0
# Net Income From Continuing And Discontinued Ope...  -2864000000.0
# Total Expenses                                      61594000000.0
# Diluted Average Shares                               1808000000.0
# Basic Average Shares                                 1808000000.0
# Diluted EPS                                                 -1.58
# Basic EPS                                                   -1.58
# Diluted NI Availto Com Stockholders                 -2864000000.0
# Net Income Common Stockholders                      -2864000000.0
# Net Income                                          -2864000000.0
# Minority Interests                                   -390000000.0
# Net Income Including Noncontrolling Interests       -2474000000.0
# Net Income Discontinuous Operations                   -32000000.0
# Net Income Continuous Operations                    -2442000000.0
# Tax Provision                                         699000000.0
# Pretax Income                                       -1743000000.0
# Other Income Expense                                -4046000000.0
# Other Non Operating Income Expenses                  1038000000.0
# Special Income Charges                              -5735000000.0
# Gain On Sale Of Business                                      0.0
# Other Special Charges                                -973000000.0
# Restructuring And Mergern Acquisition                5735000000.0
# Earnings From Equity Interest                         651000000.0
# Gain On Sale Of Security                             1038000000.0
# Net Non Operating Interest Income Expense           -1491000000.0
# Interest Expense Non Operating                       1491000000.0
# Interest Income Non Operating                         156000000.0
# Operating Income                                     3794000000.0
# Operating Expense                                   17714000000.0
# Depreciation Amortization Depletion Income Stat...   5345000000.0
# Depreciation And Amortization In Income Statement    5345000000.0
# Selling General And Administration                  12369000000.0
# Gross Profit                                        21508000000.0
# Cost Of Revenue                                     43880000000.0
# Total Revenue                                       65388000000.0
# Operating Revenue                                   65388000000.0

# %%
dis.cashflow
# Out:
#                                            2023-09-30    2022-09-30  \
# Free Cash Flow                           4897000000.0  1067000000.0
# Repurchase Of Capital Stock                       NaN           NaN
# Repayment Of Debt                       -1675000000.0 -4016000000.0
# Issuance Of Debt                           83000000.0   333000000.0
# Capital Expenditure                     -4969000000.0 -4943000000.0
# ...                                               ...           ...
# Operating Gains Losses                   -944000000.0   518000000.0
# Pension And Employee Benefit Expense        4000000.0   620000000.0
# Earnings Losses From Equity Investments  -782000000.0  -816000000.0
# Gain Loss On Investment Securities       -166000000.0   714000000.0
# Net Income From Continuing Operations    3390000000.0  3553000000.0
#
#                                            2021-09-30     2020-09-30
# Free Cash Flow                           1989000000.0   3596000000.0
# Repurchase Of Capital Stock                       NaN            0.0
# Repayment Of Debt                       -3737000000.0  -3533000000.0
# Issuance Of Debt                           64000000.0  18120000000.0
# Capital Expenditure                     -3578000000.0  -4022000000.0
# ...                                               ...            ...
# Operating Gains Losses                   -277000000.0  -1024000000.0
# Pension And Employee Benefit Expense      816000000.0    547000000.0
# Earnings Losses From Equity Investments  -761000000.0   -651000000.0
# Gain Loss On Investment Securities       -332000000.0   -920000000.0
# Net Income From Continuing Operations    2536000000.0  -2442000000.0
#
# [63 rows x 4 columns]

# %%
ticker = ["AAPL", "META", "AMZN"]

# %%
for i in ticker:
    yf.Ticker(i).income_stmt.to_csv("{}.csv".format(i))

# %% [markdown]
# __yahooquery__

# %%
yq

# %%
yq.balance_sheet().T

# %%
yq.income_statement().T

# %%
yq.cash_flow().T

# %%
ticker = ["AAPL", "META", "AMZN"]

# %%
for i in ticker:
    Ticker(i).income_statement().T.to_csv("{}.csv".format(i))

# %% [markdown]
# ## Importing Put / Call Options (Stocks)

# %%
dis

# %%
dis.option_chain()

# %%
calls = dis.option_chain()[0]
calls

# %%
puts = dis.option_chain()[1]
puts

# %% [markdown]
# ## Streaming real-time Data

# %%
import pandas as pd
import yfinance as yf
import time

# %%
yf.download("EURUSD=X", interval = "1m", period = "1d").tail()

# %%
data = yf.download("EURUSD=X", interval = "1m", period = "1d")

# %%
print(data.index[-1], data.iloc[-1, 3])

# %%
while True:
    time.sleep(5)
    data = yf.download("EURUSD=X", interval = "1m", period = "1d", progress = False)
    print(data.index[-1], data.iloc[-1, 3])

# %%
while True:
    time.sleep(60)
    data = yf.download("EURUSD=X", interval = "1m", period = "1d", progress = False)
    print(data.index[-1], data.iloc[-1, 3])

# %% [markdown]
# url = "https://finance.yahoo.com/quote/SMCI/cash-flow?p=SMCI#:~:text=Quarterly-,Download,-Expand%20All"

# %%
import requests
url = "https://finance.yahoo.com/quote/SMCI/cash-flow?p=SMCI"
response = requests.get(url)
print(response)

with open('file.py', 'wb') as file:
    file.write(response.content)
# Out:
# <Response [404]>
